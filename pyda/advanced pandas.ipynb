# %% [markdown]
# Задание 1
# Для датафрейма log из материалов занятия создайте столбец source_type по следующим правилам:
#
# если источник traffic_source равен yandex или google, то в source_type ставится organic
# для источников paid и email из России - ставим ad
# для источников paid и email не из России - ставим other
# все остальные варианты берем из traffic_source без изменений

# %%
import pandas as pd

# %%
import re

# %%
log = pd.read_csv('visit_log.csv', sep=';')
log['source_type'] = log['traffic_source']
log.loc[((log.traffic_source == 'yandex')|(log.traffic_source == 'google')), 'source_type'] = 'organic'
log.loc[((log.traffic_source == 'paid')|(log.traffic_source == 'email'))&(log.region == 'Russia'), 'source_type'] = 'ad'
log.loc[((log.traffic_source == 'paid')|(log.traffic_source == 'email'))&(log.region != 'Russia'), 'source_type'] = 'other'
log.sample(20)
# Out:
#         timestamp    visit_id                                 url     region  \
# 1486   1549989537  4d51076a88  https://host.ru/8e88d4703848cc0ec4     Russia
# 17936  1550088222  a4cbd29d0a  https://host.ru/da83c74e35e7806fe0  Australia
# 5743   1550015262  cc31ff03e4  https://host.ru/c2382eb3d6afc8d0f3     Russia
# 15853  1550075444  75fe12ff06  https://host.ru/6fda01ec57f23abc9e     Russia
# 2227   1549994093  b108fc34a6  https://host.ru/060d9bdbcba66b8bb3    Ukraine
# 10235  1550041831  e61d6212a5  https://host.ru/05e41944dd85a900a6     Russia
# 16694  1550080503  98b3dc731e  https://host.ru/a5dda93e70318570c0     Russia
# 5654   1550014698  c574e03baa  https://host.ru/5301a605bd574af1a5    Belarus
# 12967  1550057950  2227b27c7b  https://host.ru/87010dbb42ea270213    Belarus
# 7410   1550025073  7e6b0649ab  https://host.ru/05e41944dd85a900a6      China
# 2092   1549993282  9c4da20e38  https://host.ru/8880fd00cf23066541    Belarus
# 7529   1550025791  806bfedbe3  https://host.ru/c2382eb3d6afc8d0f3    Belarus
# 16828  1550081420  46b3d6a06a  https://host.ru/4adc8a29b212051b04     Russia
# 10860  1550045502  dd1ddd1cf0  https://host.ru/4adc8a29b212051b04     Russia
# 4877   1550010076  146497218a  https://host.ru/3c19b4ef7371864fa3     Russia
# 13205  1550059392  a8483ee5d5  https://host.ru/9010367b0b48d2f1b9      China
# 13314  1550060051  00d99dadcd  https://host.ru/4adc8a29b212051b04     Russia
# 18279  1550090427  e057bb6ddf  https://host.ru/f1eb4601740d627ab0    Ukraine
# 14121  1550064978  0bea530776  https://host.ru/6407d4271d7b23cdf5    Belarus
# 4603   1550008417  81c12ffca5  https://host.ru/f2297425e1328e9e35     Russia
#
#           user_id traffic_source source_type
# 1486   e4cc378d21         direct      direct
# 17936  0398203a67           paid       other
# 5743   17c665fbf4         direct      direct
# 15853  1d8a3959b8         direct      direct
# 2227   ca6a80811a           paid       other
# 10235  43c223602a         direct      direct
# 16694  0c6f54611f         direct      direct
# 5654   7ccedaf008         direct      direct
# 12967  dffc4fb0c9           paid       other
# 7410   80220465c5         google     organic
# 2092   2fd5e96d36         direct      direct
# 7529   ae5197cc57         direct      direct
# 16828  a8146a148c          email          ad
# 10860  463d94e5cc         direct      direct
# 4877   3c537624c8         google     organic
# 13205  8a0d92e795          email       other
# 13314  1dc4d7b032         direct      direct
# 18279  0c99ce6992         direct      direct
# 14121  ae19da05e6         yandex     organic
# 4603   2c3b921244         yandex     organic

# %% [markdown]
# Задание 2
# В файле URLs.txt содержатся url страниц новостного сайта. Вам необходимо отфильтровать его по адресам страниц с текстами новостей. Известно, что шаблон страницы новостей имеет внутри url следующую конструкцию: /, затем 8 цифр, затем дефис. Выполните следующие действия:
#
# Прочитайте содержимое файла с датафрейм
# Отфильтруйте страницы с текстом новостей, используя метод str.contains и регулярное выражение в соответствии с заданным шаблоном

# %%
urls = pd.read_csv('URLs.txt')
urls[urls.url.str.contains('\/\d{8}\-')].head()
# Out:
#                                                  url
# 3  /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4  /world/36007585-tramp-pridumal-kak-reshit-ukra...
# 5  /science/36157853-nasa-sobiraet-ekstrennuyu-pr...
# 6  /video/36001498-poyavilis-pervye-podrobnosti-g...
# 7  /world/36007585-tramp-pridumal-kak-reshit-ukra...

# %% [markdown]
# Домашнее задание 3
# В датафрейме data создайте столбец lemmas, в котором вычислите леммы поисковых запросов из столбца keyword. Леммы должны иметь строковый тип.

# %%
pip install pymystem3
# Out:
# Collecting pymystem3
#   Downloading https://files.pythonhosted.org/packages/00/8c/98b43c5822620458704e187a1666616c1e21a846ede8ffda493aabe11207/pymystem3-0.2.0-py3-none-any.whl
# Requirement already satisfied: requests in c:\anaconda3\lib\site-packages (from pymystem3) (2.22.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests->pymystem3) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\anaconda3\lib\site-packages (from requests->pymystem3) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\anaconda3\lib\site-packages (from requests->pymystem3) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests->pymystem3) (1.24.2)
# Installing collected packages: pymystem3
# Successfully installed pymystem3-0.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymystem3 import Mystem

# %%
data = pd.DataFrame({
    'keyword': ['курс гривны к рублю', 'доллары в рубли', '100 долларов в рублях', 'курс рубля'],
    'shows': [125076, 114173, 97534, 53546],
})
def lem(row):
    m = Mystem()
    lemmas = m.lemmatize(row['keyword'])
    return ' '.join(lemmas)
data['lemmas'] = data.apply(lem, axis=1)
data.head()
# Out:
#                  keyword   shows                        lemmas
# 0    курс гривны к рублю  125076  курс   гривна   к   рубль \n
# 1        доллары в рубли  114173         доллар   в   рубль \n
# 2  100 долларов в рублях   97534   100   доллар   в   рубль \n
# 3             курс рубля   53546               курс   рубль \n
